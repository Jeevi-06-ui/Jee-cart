# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevi-06-ui/Jee-cart/blob/main/quickstarts/Get_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Labsheet 1

# %%
def getTextLinesFromFile(fileName):
  lines  = [] # Creates an empty list called lines. This will store all lines read from the file.
with open(Test0.txt, "r") as fp:
  lines = fp.readlines() # reads all lines from the file.
return lines
#TODO: You can either ask the user here to enter the file name
fileName = "Test0.txt"
lines = getTextLinesFromFile(Test0.txt) # Calls the function and stores the returned list of lines in lines.
#print(lines)
for line in lines:
  print(line.replace("\n","")) # removes the newline character.
  #print(line)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-631141392.py in <cell line: 0>()
#       1 def getTextLinesFromFile(fileName):
#       2   lines  = [] # Creates an empty list called lines. This will store all lines read from the file.
# ----> 3 with open(Test0.txt, "r") as fp:
#       4   lines = fp.readlines() # reads all lines from the file.
#       5 return lines
#
# NameError: name 'Test0' is not defined
